# %% [markdown]
# ## import the modules

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

from pandas import *
from datetime import datetime

# %% [markdown]
# ## import the source data file for Cape Town

# %%
capetown = read_csv('CapeTown_CPT_2014.csv', skipinitialspace=True)
capetown.head()
# Out:
#        Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0  2014-1-1                28                 23                18
# 1  2014-1-2                28                 23                18
# 2  2014-1-3                27                 23                19
# 3  2014-1-4                27                 22                18
# 4  2014-1-5                26                 22                18
#
#    Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# 0          19              17             15            88             71
# 1          19              18             16            88             74
# 2          19              18             18            94             75
# 3          19              18             14            88             74
# 4          17              16             14            83             70
#
#    Min Humidity  ...  Max VisibilityKm  Mean VisibilityKm  Min VisibilitykM  \
# ...

# %% [markdown]
# ## find missing values in Events column:

# %%
capetown['Events'].isnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 360     True
# 361     True
# 362     True
# 363     True
# 364     True
# Name: Events, Length: 365, dtype: bool

# %% [markdown]
# ## fill rows with missing col values (NaN) with empty string:

# %%
capetown['Events'] = capetown['Events'].fillna('')
capetown['Events'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 360    False
# 361    False
# 362    False
# 363    False
# 364    False
# Name: Events, Length: 365, dtype: bool

# %% [markdown]
# ## drop rows with missing column values

# %%
# capetown.dropna()

# %% [markdown]
# ## check datatypes

# %%
capetown.dtypes
# Out:
# Date                           object
# Max TemperatureC                int64
# Mean TemperatureC               int64
# Min TemperatureC                int64
# Dew PointC                      int64
# MeanDew PointC                  int64
# Min DewpointC                   int64
# Max Humidity                    int64
# Mean Humidity                   int64
# Min Humidity                    int64
# Max Sea Level PressurehPa       int64
# Mean Sea Level PressurehPa      int64
# Min Sea Level PressurehPa       int64
# Max VisibilityKm              float64
# Mean VisibilityKm             float64
# Min VisibilitykM              float64
# Max Wind SpeedKm/h              int64
# Mean Wind SpeedKm/h             int64
# Max Gust SpeedKm/h            float64
# Precipitationmm               float64
# CloudCover                    float64
# Events                         object
# WindDirDegrees<br />           object
# dtype: object

# %% [markdown]
# ## set datatypes

# %%
capetown = capetown.rename(columns={'WindDirDegrees<br />' : 'WindDirDegrees'}) #rename column
capetown['WindDirDegrees'] = capetown['WindDirDegrees'].str.rstrip('<br />') #strip invalid characters
capetown['WindDirDegrees'] = capetown['WindDirDegrees'].astype('float64') #change datatype to float64
capetown['Date'] = to_datetime(capetown['Date']) #change datatype to datetime

# %% [markdown]
# ## set index to date/time column

# %%
capetown.index = capetown['Date']
capetown.head()
# Out:
#                  Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# Date
# 2014-01-01 2014-01-01                28                 23                18
# 2014-01-02 2014-01-02                28                 23                18
# 2014-01-03 2014-01-03                27                 23                19
# 2014-01-04 2014-01-04                27                 22                18
# 2014-01-05 2014-01-05                26                 22                18
#
#             Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  \
# Date
# 2014-01-01          19              17             15            88
# 2014-01-02          19              18             16            88
# 2014-01-03          19              18             18            94
# 2014-01-04          19              18             14            88
# 2014-01-05          17              16             14            83
#
#             Mean Humidity  Min Humidity  ...  Max VisibilityKm  \
# ...

# %% [markdown]
# ## for northern hemisphere, set summer to june-august
# ## for southern hemisphere, set summer to december-february

# %%
summer = capetown.loc[datetime(2014,1,1) : datetime(2014,2,28)]
summer[summer['Mean TemperatureC'] >= 25]
# Out:
#                  Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# Date
# 2014-01-21 2014-01-21                31                 25                19
# 2014-01-30 2014-01-30                31                 26                21
# 2014-01-31 2014-01-31                35                 28                20
# 2014-02-14 2014-02-14                33                 26                19
# 2014-02-15 2014-02-15                33                 28                22
# 2014-02-16 2014-02-16                36                 28                20
# 2014-02-17 2014-02-17                29                 26                22
# 2014-02-18 2014-02-18                31                 27                22
# 2014-02-25 2014-02-25                33                 26                19
# 2014-02-26 2014-02-26                34                 27                20
#
#             Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  \
# Date
# ...

# %% [markdown]
# ## find all temperatures over x
# ## plot a graph of mean temp, over the period

# %%
# %matplotlib inline
summer['Mean TemperatureC'].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## plot a graph of mean temp & precipitation, over the period

# %%
summer[['Mean TemperatureC', 'Precipitationmm']].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## note best combination of temp/precipitation on graph

# %%
feb = summer.loc[datetime(2014,2,14) : datetime(2014,2,28)]
feb[['Mean TemperatureC', 'Precipitationmm']].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>
